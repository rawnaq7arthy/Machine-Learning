# %%
import tensorflow as tf

# %%
# 1. Sequential model with 5 layers
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,), name="Input_Layer"),
    tf.keras.layers.Dense(128, activation='relu', name="Hidden_Layer_1"),
    tf.keras.layers.Dense(64, activation='relu', name="Hidden_Layer_2"),
    tf.keras.layers.Dense(32, activation='relu', name="Hidden_Layer_3"),
    tf.keras.layers.Dense(16, activation='relu', name="Hidden_Layer_4"),
    tf.keras.layers.Dense(1, name="Output_Layer"),
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer_1 (Dense)          │ (None, 128)            │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_4 (Dense)          │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │            17 │
# ...

# %% [markdown]
# # Sequential API

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=[1], name="Input_Layer"),
    tf.keras.layers.Dense(64, activation="relu", name="Hidden_Layer_1"),
    tf.keras.layers.Dense(32, activation="relu", name="Hidden_Layer_2"),
    tf.keras.layers.Dense(16, activation="relu", name="Hidden_Layer_3"),
    tf.keras.layers.Dense(8, activation="relu", name="Hidden_Layer_4"),
    tf.keras.layers.Dense(1, activation="relu", name="Output_Layer"),
])

tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)

# %% [markdown]
# # Functional API

# %%
input_layer = tf.keras.layers.Input(shape=[1], name="Input_Layer")
layer_1 = tf.keras.layers.Dense(64, activation='relu', name="Hidden_Layer_1")(input_layer)
layer_2 = tf.keras.layers.Dense(32, activation='relu', name="Hidden_Layer_2")(layer_1)
layer_3 = tf.keras.layers.Dense(16, activation='relu', name="Hidden_Layer_3")(layer_2)
layer_4 = tf.keras.layers.Dense(8, activation='relu', name="Hidden_Layer_4")(layer_3)
output_layer = tf.keras.layers.Dense(1, name="Output_Layer")(layer_4)

model = tf.keras.Model(inputs=input_layer, outputs=output_layer)

tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)

# %% [markdown]
# ## Non-sequential Neural Netowrk

# %%
input_layer = tf.keras.layers.Input(shape=[10], name="Input_Layer")
hidden1 = tf.keras.layers.Dense(64, activation="relu", name="Hidden_Layer_1")(input_layer)
hidden2 = tf.keras.layers.Dense(32, activation="relu", name="Hidden_Layer_2")(hidden1)
hidden3 = tf.keras.layers.Dense(16, activation="relu", name="Hidden_Layer_3")(hidden2)
hidden4 = tf.keras.layers.Dense(8, activation="relu", name="Hidden_Layer_4")(hidden3)
concat = tf.keras.layers.Concatenate(name="Concatenation_Layer")([input_layer, hidden4])
output = tf.keras.layers.Dense(1, name="Output_Layer")(concat)

model = tf.keras.Model(inputs=[input_layer], outputs=[output])

tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)

# %% [markdown]
# ## Non-sequential Neural Netowrk - Exmaple 2

# %%
input_A = tf.keras.layers.Input(shape=[5], name="Input_A")
input_B = tf.keras.layers.Input(shape=[6], name="Input_B")

hidden1 = tf.keras.layers.Dense(64, activation="relu", name="Hidden_Layer_1")(input_B)
hidden2 = tf.keras.layers.Dense(32, activation="relu", name="Hidden_Layer_2")(hidden1)
hidden3 = tf.keras.layers.Dense(16, activation="relu", name="Hidden_Layer_3")(hidden2)
hidden4 = tf.keras.layers.Dense(8, activation="relu", name="Hidden_Layer_4")(hidden3)

concat = tf.keras.layers.concatenate([input_A, hidden4], name="Concatenation_Layer")
output = tf.keras.layers.Dense(1, name="Output_Layer")(concat)

model = tf.keras.Model(inputs=[input_A, input_B], outputs=[output])

tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)
