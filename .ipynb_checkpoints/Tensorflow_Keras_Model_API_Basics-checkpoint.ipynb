# %%
pip install pydot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import numpy as np
# Out:
# 2025-06-25 14:33:04.999295: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Generate random training data
X = tf.random.uniform((100, 1))
y = (X + 5) * 0.3

print("Input shape:", X.shape)
print("Target shape:", y.shape)
# Out:
# Input shape: (100, 1)
# Target shape: (100, 1)

# %%
import tensorflow as tf

# Define the model architecture with 5 layers (4 hidden + 1 output)
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,), name="Input_Layer"),
    tf.keras.layers.Dense(128, activation='relu', name="Hidden_Layer_1"),
    tf.keras.layers.Dense(64, activation='relu', name="Hidden_Layer_2"),
    tf.keras.layers.Dense(32, activation='relu', name="Hidden_Layer_3"),
    tf.keras.layers.Dense(16, activation='relu', name="Hidden_Layer_4"),
    tf.keras.layers.Dense(1, name="Output_Layer"),  # Output layer
])

# Show model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Hidden_Layer_1 (Dense)          │ (None, 128)            │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_2 (Dense)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_3 (Dense)          │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Hidden_Layer_4 (Dense)          │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output_Layer (Dense)            │ (None, 1)              │            17 │
# ...

# %%
# Visualize model
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True, rankdir="TB", dpi=96)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mse')

# %%
# Train the model
model.fit(X, y, epochs=10)

# Test prediction on a single value
test_input = np.array([[9]])
predicted = model.predict(test_input)
expected = (test_input + 5) * 0.3
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6806
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4797
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2322
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9598
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6616
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3078
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9307
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5448
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2778
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1449
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
print("Predicted:", predicted)
print("Expected (true value):", expected)
# Out:
# Predicted: [[16.230856]]
# Expected (true value): [[4.2]]

# %%
# Predict on new test data
X_test = tf.random.uniform((10, 1))
predictions = model.predict(X_test)

print("Test Predictions:\n", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Test Predictions:
#  [[1.72079  ]
#  [1.0755128]
#  [1.6493334]
#  [1.0901661]
#  [1.4355891]
#  [1.5867727]
#  [1.3814561]
#  [0.912132 ]
#  [0.8979257]
#  [1.6888354]]
